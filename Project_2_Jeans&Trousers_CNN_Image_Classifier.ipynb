# %%
import os
import numpy as np
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
import scipy
import pylab as pl
import matplotlib.cm as cm
# %matplotlib inline

input_shape = (150, 150, 3)
img_width = 150
img_height = 150

nb_train_samples = 200
nb_validation_samples = 200
batch_size = 32
epochs = 50
# Out:
# Using TensorFlow backend.

# %%
train_data_dir = 'E:/jeans_trousers_train'
validation_data_dir = 'E:/jeans_trousers_test'

# %%
# used to rescale the pixel values from [0, 255] to [0, 1] interval
datagen = ImageDataGenerator(rescale=1./255)

# automagically retrieve images and their classes for train and validation sets
train_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=16,
        class_mode='binary')

validation_generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        class_mode='binary')
# Out:
# Found 200 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

print(model.summary())
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import keras
keras.utils.plot_model(
    model,
    to_file="model.png"
)

# %%
model.compile(loss='binary_crossentropy',
             optimizer='rmsprop',
             metrics=['accuracy'])

train_datagen_augmented = ImageDataGenerator(
             rescale=1./255,         # normalize pixel values to [0,1]
             shear_range=0.2,       # randomly applies shearing tranformation
             zoom_range=0.2,        # randomly applies shearing tranformation
             rotation_range = 30,
             horizontal_flip=True)  # randomly flip the images

# same code as before
train_generator_augmented = train_datagen_augmented.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Found 200 images belonging to 2 classes.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 6/6 [==============================] - 7s 1s/step - loss: 3.7055 - accuracy: 0.4583 - val_loss: 0.7053 - val_accuracy: 0.5052
# Epoch 2/50
# 6/6 [==============================] - 6s 955ms/step - loss: 0.7570 - accuracy: 0.4773 - val_loss: 0.6897 - val_accuracy: 0.5060
# Epoch 3/50
# 6/6 [==============================] - 6s 973ms/step - loss: 0.6732 - accuracy: 0.5227 - val_loss: 0.6904 - val_accuracy: 0.5000
# Epoch 4/50
# 6/6 [==============================] - 6s 936ms/step - loss: 0.7304 - accuracy: 0.4375 - val_loss: 0.6906 - val_accuracy: 0.4643
# Epoch 5/50
# 6/6 [==============================] - 6s 986ms/step - loss: 0.7027 - accuracy: 0.5521 - val_loss: 0.6925 - val_accuracy: 0.5655
# Epoch 6/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.6941 - accuracy: 0.5341 - val_loss: 0.6851 - val_accuracy: 0.5417
# Epoch 7/50
# 6/6 [==============================] - 6s 984ms/step - loss: 0.6721 - accuracy: 0.5417 - val_loss: 0.6877 - val_accuracy: 0.4821
# Epoch 8/50
# 6/6 [==============================] - 6s 940ms/step - loss: 0.7249 - accuracy: 0.4792 - val_loss: 0.6915 - val_accuracy: 0.5885
# Epoch 9/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.7063 - accuracy: 0.5625 - val_loss: 0.6932 - val_accuracy: 0.4881
# Epoch 10/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.7007 - accuracy: 0.5000 - val_loss: 0.6908 - val_accuracy: 0.4881
# Epoch 11/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.6814 - accuracy: 0.5833 - val_loss: 0.6891 - val_accuracy: 0.4702
# Epoch 12/50
# 6/6 [==============================] - 6s 951ms/step - loss: 0.7156 - accuracy: 0.5104 - val_loss: 0.6918 - val_accuracy: 0.6310
# Epoch 13/50
# 6/6 [==============================] - 5s 896ms/step - loss: 0.6844 - accuracy: 0.5909 - val_loss: 0.6912 - val_accuracy: 0.5774
# Epoch 14/50
# 6/6 [==============================] - 6s 922ms/step - loss: 0.6673 - accuracy: 0.5938 - val_loss: 0.6887 - val_accuracy: 0.7857
# Epoch 15/50
# 6/6 [==============================] - 5s 894ms/step - loss: 0.6736 - accuracy: 0.5455 - val_loss: 0.6799 - val_accuracy: 0.6146
# Epoch 16/50
# 6/6 [==============================] - 6s 999ms/step - loss: 0.5973 - accuracy: 0.6705 - val_loss: 0.6645 - val_accuracy: 0.5774
# Epoch 17/50
# 6/6 [==============================] - 6s 969ms/step - loss: 0.6697 - accuracy: 0.5938 - val_loss: 0.6501 - val_accuracy: 0.7679
# Epoch 18/50
# 6/6 [==============================] - 6s 990ms/step - loss: 0.6254 - accuracy: 0.6042 - val_loss: 0.6358 - val_accuracy: 0.7619
# Epoch 19/50
# 6/6 [==============================] - 5s 908ms/step - loss: 0.5906 - accuracy: 0.6591 - val_loss: 0.6235 - val_accuracy: 0.8095
# Epoch 20/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.5730 - accuracy: 0.7083 - val_loss: 0.6265 - val_accuracy: 0.8095
# Epoch 21/50
# 6/6 [==============================] - 5s 891ms/step - loss: 0.5651 - accuracy: 0.6979 - val_loss: 0.6050 - val_accuracy: 0.8095
# Epoch 22/50
# 6/6 [==============================] - 6s 928ms/step - loss: 0.5186 - accuracy: 0.7614 - val_loss: 0.5954 - val_accuracy: 0.8333
# Epoch 23/50
# 6/6 [==============================] - 6s 933ms/step - loss: 0.4714 - accuracy: 0.7841 - val_loss: 0.6070 - val_accuracy: 0.7798
# Epoch 24/50
# 6/6 [==============================] - 6s 979ms/step - loss: 0.4393 - accuracy: 0.8333 - val_loss: 0.5812 - val_accuracy: 0.8571
# Epoch 25/50
# 6/6 [==============================] - 5s 898ms/step - loss: 0.4170 - accuracy: 0.7955 - val_loss: 0.5520 - val_accuracy: 0.7083
# Epoch 26/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.4292 - accuracy: 0.7708 - val_loss: 0.5233 - val_accuracy: 0.8690
# Epoch 27/50
# 6/6 [==============================] - 13s 2s/step - loss: 0.3160 - accuracy: 0.8854 - val_loss: 0.3695 - val_accuracy: 0.9048
# Epoch 28/50
# 6/6 [==============================] - 14s 2s/step - loss: 0.3008 - accuracy: 0.8333 - val_loss: 0.3211 - val_accuracy: 0.8690
# Epoch 29/50
# 6/6 [==============================] - 12s 2s/step - loss: 0.2652 - accuracy: 0.9091 - val_loss: 0.4940 - val_accuracy: 0.8594
# Epoch 30/50
# 6/6 [==============================] - 13s 2s/step - loss: 0.3149 - accuracy: 0.8977 - val_loss: 0.5038 - val_accuracy: 0.7381
# Epoch 31/50
# 6/6 [==============================] - 13s 2s/step - loss: 0.3160 - accuracy: 0.8750 - val_loss: 0.4017 - val_accuracy: 0.8690
# Epoch 32/50
# 6/6 [==============================] - 13s 2s/step - loss: 0.2684 - accuracy: 0.8864 - val_loss: 0.4966 - val_accuracy: 0.8393
# Epoch 33/50
# 6/6 [==============================] - 18s 3s/step - loss: 0.3115 - accuracy: 0.9091 - val_loss: 0.2870 - val_accuracy: 0.9286
# Epoch 34/50
# 6/6 [==============================] - 14s 2s/step - loss: 0.1549 - accuracy: 0.9479 - val_loss: 0.2701 - val_accuracy: 0.8571
# Epoch 35/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.1998 - accuracy: 0.9375 - val_loss: 0.4767 - val_accuracy: 0.8929
# Epoch 36/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.1566 - accuracy: 0.9479 - val_loss: 0.6450 - val_accuracy: 0.8021
# Epoch 37/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.3544 - accuracy: 0.8977 - val_loss: 0.3554 - val_accuracy: 0.8690
# Epoch 38/50
# 6/6 [==============================] - 12s 2s/step - loss: 0.1701 - accuracy: 0.9479 - val_loss: 0.4934 - val_accuracy: 0.8929
# Epoch 39/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.2626 - accuracy: 0.8864 - val_loss: 0.9767 - val_accuracy: 0.7321
# Epoch 40/50
# 6/6 [==============================] - 12s 2s/step - loss: 0.2794 - accuracy: 0.9271 - val_loss: 0.2872 - val_accuracy: 0.9226
# Epoch 41/50
# 6/6 [==============================] - 10s 2s/step - loss: 0.2694 - accuracy: 0.9432 - val_loss: 0.2264 - val_accuracy: 0.8869
# Epoch 42/50
# 6/6 [==============================] - 12s 2s/step - loss: 0.1900 - accuracy: 0.9375 - val_loss: 0.2905 - val_accuracy: 0.8988
# Epoch 43/50
# 6/6 [==============================] - 13s 2s/step - loss: 0.0770 - accuracy: 0.9659 - val_loss: 0.2050 - val_accuracy: 0.8594
# Epoch 44/50
# 6/6 [==============================] - 10s 2s/step - loss: 0.1274 - accuracy: 0.9583 - val_loss: 0.2860 - val_accuracy: 0.9048
# Epoch 45/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.1479 - accuracy: 0.9375 - val_loss: 0.5578 - val_accuracy: 0.8452
# Epoch 46/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.2826 - accuracy: 0.9205 - val_loss: 0.3226 - val_accuracy: 0.8810
# Epoch 47/50
# 6/6 [==============================] - 10s 2s/step - loss: 0.0890 - accuracy: 0.9773 - val_loss: 0.2935 - val_accuracy: 0.8988
# Epoch 48/50
# 6/6 [==============================] - 11s 2s/step - loss: 0.2240 - accuracy: 0.9167 - val_loss: 0.1609 - val_accuracy: 0.8571
# Epoch 49/50
# 6/6 [==============================] - 10s 2s/step - loss: 0.1101 - accuracy: 0.9583 - val_loss: 1.2125 - val_accuracy: 0.8393
# Epoch 50/50
# 6/6 [==============================] - 14s 2s/step - loss: 0.0878 - accuracy: 0.9659 - val_loss: 0.6765 - val_accuracy: 0.7969

# %%
# plotting out loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
