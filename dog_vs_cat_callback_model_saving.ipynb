# %% [markdown]
# <a href="https://colab.research.google.com/github/ind-kum/DEEP-LEARNING-PROJECTS/blob/master/dog_vs_cat_callback_model_saving.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.models import load_model
import os
from keras.utils import np_utils
from keras import backend as K
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

batch_size = 32
num_classes = 10
epochs = 50

# %%
# Loads the CIFAR dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Display our data shape/dimensions
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# formate our training data by normalizing and changing data type
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# Now we one hot encode outputs
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
model = Sequential()

# Padding = 'same' results in padding the input such that
# the output has the some Length as the original input
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same',))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# initiate Adadelta optimize
opt = keras.optimizers.Adadelta()

# Lets create our model
model.compile(loss = 'categorical_crossentropy',
             optimizer = opt,
             metrics = ['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 13, 13, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 13, 13, 64)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 6, 6, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 2304)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1180160
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# activation_5 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Let's create ModelCheckpoint
checkpoint = ModelCheckpoint(r"C:\Users\INDROCKS\cifar_Checkpoint.h5",
                             moniter="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

# Let's create EarlyStopping
earlystop = EarlyStopping(monitor = 'val_loss', # value being monitored for improvement
                          min_delta = 0, #Abs value and it the min change erequired before we stop
                          patience = 3, #Number of epochs we wait before stopping
                          verbose = 1,
                          restore_best_weights = True)  #keeps the best weights once stopped

# Let's Reduce the learning rate
reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                             factor = 0.2,
                             patience = 3,
                             verbose = 1,
                             min_delta = 0.0001)
# we put our call backs into a callback list
callbacks = [earlystop, checkpoint, reduce_lr]

# %%
history = model.fit(x_train, y_train,
                   batch_size=batch_size,
                   epochs=epochs,
                   callbacks = callbacks,
                   validation_data=(x_test, y_test),
                   shuffle=True)

model.save("cifar_simple_cnn_2.h5")

# Evaluate the performace of our trained model
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 239s 152ms/step - loss: 2.3046 - accuracy: 0.1062 - val_loss: 2.2964 - val_accuracy: 0.1131
#
# Epoch 00001: val_loss improved from inf to 2.29641, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 2/50
# 1563/1563 [==============================] - 238s 153ms/step - loss: 2.2958 - accuracy: 0.1121 - val_loss: 2.2901 - val_accuracy: 0.1103
#
# Epoch 00002: val_loss improved from 2.29641 to 2.29011, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 3/50
# 1563/1563 [==============================] - 238s 153ms/step - loss: 2.2900 - accuracy: 0.1164 - val_loss: 2.2825 - val_accuracy: 0.1133
#
# Epoch 00003: val_loss improved from 2.29011 to 2.28250, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 4/50
# 1563/1563 [==============================] - 239s 153ms/step - loss: 2.2815 - accuracy: 0.1262 - val_loss: 2.2716 - val_accuracy: 0.1231
#
# Epoch 00004: val_loss improved from 2.28250 to 2.27165, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 5/50
# 1563/1563 [==============================] - 240s 154ms/step - loss: 2.2706 - accuracy: 0.1296 - val_loss: 2.2563 - val_accuracy: 0.1507
#
# Epoch 00005: val_loss improved from 2.27165 to 2.25630, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 6/50
# 1563/1563 [==============================] - 239s 153ms/step - loss: 2.2531 - accuracy: 0.1495 - val_loss: 2.2323 - val_accuracy: 0.1872
#
# Epoch 00006: val_loss improved from 2.25630 to 2.23235, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 7/50
# 1563/1563 [==============================] - 238s 152ms/step - loss: 2.2302 - accuracy: 0.1671 - val_loss: 2.1989 - val_accuracy: 0.2246
#
# Epoch 00007: val_loss improved from 2.23235 to 2.19893, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 8/50
# 1563/1563 [==============================] - 240s 154ms/step - loss: 2.1978 - accuracy: 0.1838 - val_loss: 2.1590 - val_accuracy: 0.2435
#
# Epoch 00008: val_loss improved from 2.19893 to 2.15896, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 9/50
# 1563/1563 [==============================] - 239s 153ms/step - loss: 2.1591 - accuracy: 0.1970 - val_loss: 2.1200 - val_accuracy: 0.2526
#
# Epoch 00009: val_loss improved from 2.15896 to 2.11997, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 10/50
# 1563/1563 [==============================] - 240s 154ms/step - loss: 2.1271 - accuracy: 0.2081 - val_loss: 2.0872 - val_accuracy: 0.2587
#
# Epoch 00010: val_loss improved from 2.11997 to 2.08719, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 11/50
# 1563/1563 [==============================] - 242s 155ms/step - loss: 2.0952 - accuracy: 0.2232 - val_loss: 2.0621 - val_accuracy: 0.2676
#
# Epoch 00011: val_loss improved from 2.08719 to 2.06205, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 12/50
# 1563/1563 [==============================] - 242s 155ms/step - loss: 2.0789 - accuracy: 0.2239 - val_loss: 2.0436 - val_accuracy: 0.2675
#
# Epoch 00012: val_loss improved from 2.06205 to 2.04358, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 13/50
# 1563/1563 [==============================] - 243s 155ms/step - loss: 2.0632 - accuracy: 0.2275 - val_loss: 2.0294 - val_accuracy: 0.2737
#
# Epoch 00013: val_loss improved from 2.04358 to 2.02939, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 14/50
# 1563/1563 [==============================] - 243s 155ms/step - loss: 2.0496 - accuracy: 0.2334 - val_loss: 2.0176 - val_accuracy: 0.2763
#
# Epoch 00014: val_loss improved from 2.02939 to 2.01757, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 15/50
# 1563/1563 [==============================] - 240s 154ms/step - loss: 2.0478 - accuracy: 0.2381 - val_loss: 2.0073 - val_accuracy: 0.2804
#
# Epoch 00015: val_loss improved from 2.01757 to 2.00726, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 16/50
# 1563/1563 [==============================] - 242s 155ms/step - loss: 2.0282 - accuracy: 0.2445 - val_loss: 1.9980 - val_accuracy: 0.2866
#
# Epoch 00016: val_loss improved from 2.00726 to 1.99797, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 17/50
# 1563/1563 [==============================] - 242s 155ms/step - loss: 2.0237 - accuracy: 0.2464 - val_loss: 1.9897 - val_accuracy: 0.2880
#
# Epoch 00017: val_loss improved from 1.99797 to 1.98972, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 18/50
# 1563/1563 [==============================] - 243s 155ms/step - loss: 2.0121 - accuracy: 0.2552 - val_loss: 1.9808 - val_accuracy: 0.2920
#
# Epoch 00018: val_loss improved from 1.98972 to 1.98082, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 19/50
# 1563/1563 [==============================] - 245s 157ms/step - loss: 2.0098 - accuracy: 0.2527 - val_loss: 1.9727 - val_accuracy: 0.2959
#
# Epoch 00019: val_loss improved from 1.98082 to 1.97271, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 20/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9984 - accuracy: 0.2624 - val_loss: 1.9643 - val_accuracy: 0.2988
#
# Epoch 00020: val_loss improved from 1.97271 to 1.96428, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 21/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9903 - accuracy: 0.2611 - val_loss: 1.9564 - val_accuracy: 0.3016
#
# Epoch 00021: val_loss improved from 1.96428 to 1.95639, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 22/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9849 - accuracy: 0.2701 - val_loss: 1.9480 - val_accuracy: 0.3034
#
# Epoch 00022: val_loss improved from 1.95639 to 1.94797, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 23/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9764 - accuracy: 0.2727 - val_loss: 1.9398 - val_accuracy: 0.3080
#
# Epoch 00023: val_loss improved from 1.94797 to 1.93977, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 24/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9750 - accuracy: 0.2767 - val_loss: 1.9311 - val_accuracy: 0.3115
#
# Epoch 00024: val_loss improved from 1.93977 to 1.93106, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 25/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9593 - accuracy: 0.2771 - val_loss: 1.9226 - val_accuracy: 0.3159
#
# Epoch 00025: val_loss improved from 1.93106 to 1.92261, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 26/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9581 - accuracy: 0.2816 - val_loss: 1.9139 - val_accuracy: 0.3200
#
# Epoch 00026: val_loss improved from 1.92261 to 1.91385, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 27/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9495 - accuracy: 0.2829 - val_loss: 1.9052 - val_accuracy: 0.3233
#
# Epoch 00027: val_loss improved from 1.91385 to 1.90522, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 28/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9423 - accuracy: 0.2878 - val_loss: 1.8971 - val_accuracy: 0.3283
#
# Epoch 00028: val_loss improved from 1.90522 to 1.89713, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 29/50
# 1563/1563 [==============================] - 244s 156ms/step - loss: 1.9361 - accuracy: 0.2893 - val_loss: 1.8879 - val_accuracy: 0.3334
#
# Epoch 00029: val_loss improved from 1.89713 to 1.88786, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 30/50
# 1563/1563 [==============================] - 245s 157ms/step - loss: 1.9219 - accuracy: 0.2999 - val_loss: 1.8787 - val_accuracy: 0.3355
#
# Epoch 00030: val_loss improved from 1.88786 to 1.87871, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 31/50
# 1563/1563 [==============================] - 245s 157ms/step - loss: 1.9156 - accuracy: 0.3040 - val_loss: 1.8691 - val_accuracy: 0.3399
#
# Epoch 00031: val_loss improved from 1.87871 to 1.86913, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 32/50
# 1563/1563 [==============================] - 246s 158ms/step - loss: 1.9171 - accuracy: 0.3014 - val_loss: 1.8605 - val_accuracy: 0.3450
#
# Epoch 00032: val_loss improved from 1.86913 to 1.86053, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 33/50
# 1563/1563 [==============================] - 247s 158ms/step - loss: 1.9003 - accuracy: 0.3072 - val_loss: 1.8502 - val_accuracy: 0.3463
#
# Epoch 00033: val_loss improved from 1.86053 to 1.85025, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 34/50
# 1563/1563 [==============================] - 249s 159ms/step - loss: 1.8900 - accuracy: 0.3107 - val_loss: 1.8408 - val_accuracy: 0.3475
#
# Epoch 00034: val_loss improved from 1.85025 to 1.84078, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 35/50
# 1563/1563 [==============================] - 253s 162ms/step - loss: 1.8856 - accuracy: 0.3113 - val_loss: 1.8315 - val_accuracy: 0.3526
#
# Epoch 00035: val_loss improved from 1.84078 to 1.83149, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 36/50
# 1563/1563 [==============================] - 251s 161ms/step - loss: 1.8759 - accuracy: 0.3184 - val_loss: 1.8239 - val_accuracy: 0.3547
#
# Epoch 00036: val_loss improved from 1.83149 to 1.82391, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 37/50
# 1563/1563 [==============================] - 246s 158ms/step - loss: 1.8682 - accuracy: 0.3177 - val_loss: 1.8135 - val_accuracy: 0.3597
#
# Epoch 00037: val_loss improved from 1.82391 to 1.81355, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 38/50
# 1563/1563 [==============================] - 248s 158ms/step - loss: 1.8558 - accuracy: 0.3259 - val_loss: 1.8056 - val_accuracy: 0.3620
#
# Epoch 00038: val_loss improved from 1.81355 to 1.80557, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 39/50
# 1563/1563 [==============================] - 247s 158ms/step - loss: 1.8457 - accuracy: 0.3318 - val_loss: 1.7964 - val_accuracy: 0.3652
#
# Epoch 00039: val_loss improved from 1.80557 to 1.79642, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 40/50
# 1563/1563 [==============================] - 246s 157ms/step - loss: 1.8392 - accuracy: 0.3353 - val_loss: 1.7869 - val_accuracy: 0.3686
#
# Epoch 00040: val_loss improved from 1.79642 to 1.78692, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 41/50
# 1563/1563 [==============================] - 245s 157ms/step - loss: 1.8432 - accuracy: 0.3284 - val_loss: 1.7802 - val_accuracy: 0.3709
#
# Epoch 00041: val_loss improved from 1.78692 to 1.78023, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 42/50
# 1563/1563 [==============================] - 248s 158ms/step - loss: 1.8240 - accuracy: 0.3378 - val_loss: 1.7692 - val_accuracy: 0.3733
#
# Epoch 00042: val_loss improved from 1.78023 to 1.76917, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 43/50
# 1563/1563 [==============================] - 247s 158ms/step - loss: 1.8175 - accuracy: 0.3389 - val_loss: 1.7631 - val_accuracy: 0.3747
#
# Epoch 00043: val_loss improved from 1.76917 to 1.76307, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 44/50
# 1563/1563 [==============================] - 246s 158ms/step - loss: 1.8041 - accuracy: 0.3425 - val_loss: 1.7543 - val_accuracy: 0.3792
#
# Epoch 00044: val_loss improved from 1.76307 to 1.75432, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 45/50
# 1563/1563 [==============================] - 247s 158ms/step - loss: 1.8004 - accuracy: 0.3473 - val_loss: 1.7477 - val_accuracy: 0.3818
#
# Epoch 00045: val_loss improved from 1.75432 to 1.74766, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 46/50
# 1563/1563 [==============================] - 247s 158ms/step - loss: 1.7906 - accuracy: 0.3474 - val_loss: 1.7388 - val_accuracy: 0.3844
#
# Epoch 00046: val_loss improved from 1.74766 to 1.73877, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 47/50
# 1563/1563 [==============================] - 246s 157ms/step - loss: 1.7823 - accuracy: 0.3500 - val_loss: 1.7309 - val_accuracy: 0.3855
#
# Epoch 00047: val_loss improved from 1.73877 to 1.73090, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 48/50
# 1563/1563 [==============================] - 248s 158ms/step - loss: 1.7851 - accuracy: 0.3500 - val_loss: 1.7215 - val_accuracy: 0.3890
#
# Epoch 00048: val_loss improved from 1.73090 to 1.72148, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 49/50
# 1563/1563 [==============================] - 249s 160ms/step - loss: 1.7719 - accuracy: 0.3534 - val_loss: 1.7146 - val_accuracy: 0.3905
#
# Epoch 00049: val_loss improved from 1.72148 to 1.71459, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# Epoch 50/50
# 1563/1563 [==============================] - 247s 158ms/step - loss: 1.7660 - accuracy: 0.3543 - val_loss: 1.7071 - val_accuracy: 0.3934
#
# Epoch 00050: val_loss improved from 1.71459 to 1.70713, saving model to C:\Users\INDROCKS\cifar_Checkpoint.h5
# 313/313 [==============================] - 11s 36ms/step - loss: 1.7071 - accuracy: 0.3934
# Test loss: 1.7071349620819092
# Test accuracy: 0.39340001344680786

# %%
# plotting out loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
