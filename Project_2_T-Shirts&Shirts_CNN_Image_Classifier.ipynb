# %%
import os
import numpy as np
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras import optimizers
import scipy
import pylab as pl
import matplotlib.cm as cm
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
input_shape = (150, 150, 3)
img_width = 150
img_height = 150

nb_train_samples = 200
nb_validation_samples = 200
batch_size = 32
epochs = 50

train_data_dir = 'E:/T-Shirts&Shirts/train'
validation_data_dir = 'E:/T-Shirts&Shirts/test'

# %%
# used to rescale the pixel values from [0, 255] to [0, 1] interval
datagen = ImageDataGenerator(rescale=1./255)

# automagically retrieve images and their classes for train and validation sets
train_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=16,
        class_mode='binary')

validation_generator = datagen.flow_from_directory(
        validation_data_dir,
        target_size=(img_width, img_height),
        class_mode='binary')
# Out:
# Found 200 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

print(model.summary())
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 148, 148, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 32)        9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 72, 72, 32)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 32)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 36, 36, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1183808
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_5 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import keras
keras.utils.plot_model(
    model,
    to_file="model.png"
)

# %%
model.compile(loss='binary_crossentropy',
             optimizer='rmsprop',
             metrics=['accuracy'])

train_datagen_augmented = ImageDataGenerator(
             rescale=1./255,         # normalize pixel values to [0,1]
             shear_range=0.2,       # randomly applies shearing tranformation
             zoom_range=0.2,        # randomly applies shearing tranformation
             rotation_range = 30,
             horizontal_flip=True)  # randomly flip the images

# same code as before
train_generator_augmented = train_datagen_augmented.flow_from_directory(
        train_data_dir,
        target_size=(img_width, img_height),
        batch_size=batch_size,
        class_mode='binary')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\ops\nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Found 200 images belonging to 2 classes.

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/50
# 6/6 [==============================] - 7s 1s/step - loss: 1.5671 - accuracy: 0.5000 - val_loss: 0.6939 - val_accuracy: 0.4427
# Epoch 2/50
# 6/6 [==============================] - 6s 927ms/step - loss: 0.6812 - accuracy: 0.5682 - val_loss: 0.6994 - val_accuracy: 0.4881
# Epoch 3/50
# 6/6 [==============================] - 6s 942ms/step - loss: 0.7687 - accuracy: 0.4659 - val_loss: 0.6946 - val_accuracy: 0.4286
# Epoch 4/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.6896 - accuracy: 0.5833 - val_loss: 0.6924 - val_accuracy: 0.4881
# Epoch 5/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.6898 - accuracy: 0.5938 - val_loss: 0.6932 - val_accuracy: 0.5179
# Epoch 6/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.6788 - accuracy: 0.6146 - val_loss: 0.6913 - val_accuracy: 0.6310
# Epoch 7/50
# 6/6 [==============================] - 6s 953ms/step - loss: 0.6526 - accuracy: 0.6477 - val_loss: 0.6861 - val_accuracy: 0.5536
# Epoch 8/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.6783 - accuracy: 0.6023 - val_loss: 0.6516 - val_accuracy: 0.6094
# Epoch 9/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.6070 - accuracy: 0.6667 - val_loss: 0.6675 - val_accuracy: 0.6786
# Epoch 10/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.7409 - accuracy: 0.7159 - val_loss: 0.6523 - val_accuracy: 0.8512
# Epoch 11/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.5640 - accuracy: 0.7083 - val_loss: 0.5629 - val_accuracy: 0.7619
# Epoch 12/50
# 6/6 [==============================] - 6s 941ms/step - loss: 0.5155 - accuracy: 0.7500 - val_loss: 0.6224 - val_accuracy: 0.7321
# Epoch 13/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.5995 - accuracy: 0.7188 - val_loss: 0.5187 - val_accuracy: 0.8036
# Epoch 14/50
# 6/6 [==============================] - 6s 968ms/step - loss: 0.5985 - accuracy: 0.6705 - val_loss: 0.6192 - val_accuracy: 0.7917
# Epoch 15/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.3912 - accuracy: 0.8750 - val_loss: 0.5409 - val_accuracy: 0.8021
# Epoch 16/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.4466 - accuracy: 0.7917 - val_loss: 0.4999 - val_accuracy: 0.8274
# Epoch 17/50
# 6/6 [==============================] - 12s 2s/step - loss: 0.4285 - accuracy: 0.7841 - val_loss: 0.5731 - val_accuracy: 0.8393
# Epoch 18/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.4360 - accuracy: 0.8182 - val_loss: 0.5266 - val_accuracy: 0.7917
# Epoch 19/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.4084 - accuracy: 0.8542 - val_loss: 0.5445 - val_accuracy: 0.8274
# Epoch 20/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.3289 - accuracy: 0.8750 - val_loss: 0.5232 - val_accuracy: 0.8095
# Epoch 21/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.2953 - accuracy: 0.8438 - val_loss: 0.6118 - val_accuracy: 0.7679
# Epoch 22/50
# 6/6 [==============================] - 9s 1s/step - loss: 0.2924 - accuracy: 0.9062 - val_loss: 0.3863 - val_accuracy: 0.8281
# Epoch 23/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.4690 - accuracy: 0.8229 - val_loss: 0.4129 - val_accuracy: 0.8393
# Epoch 24/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.2371 - accuracy: 0.9091 - val_loss: 0.5610 - val_accuracy: 0.8393
# Epoch 25/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.2449 - accuracy: 0.8864 - val_loss: 0.2953 - val_accuracy: 0.8571
# Epoch 26/50
# 6/6 [==============================] - 6s 947ms/step - loss: 0.2806 - accuracy: 0.8854 - val_loss: 0.3222 - val_accuracy: 0.8274
# Epoch 27/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.2788 - accuracy: 0.8958 - val_loss: 0.6399 - val_accuracy: 0.7679
# Epoch 28/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.2683 - accuracy: 0.8864 - val_loss: 0.2846 - val_accuracy: 0.8512
# Epoch 29/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.2081 - accuracy: 0.8864 - val_loss: 0.6016 - val_accuracy: 0.8125
# Epoch 30/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.2362 - accuracy: 0.8646 - val_loss: 0.3200 - val_accuracy: 0.8631
# Epoch 31/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.3306 - accuracy: 0.8864 - val_loss: 0.3261 - val_accuracy: 0.7440
# Epoch 32/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.2636 - accuracy: 0.8854 - val_loss: 0.2860 - val_accuracy: 0.8393
# Epoch 33/50
# 6/6 [==============================] - 8s 1s/step - loss: 0.2525 - accuracy: 0.8750 - val_loss: 0.4693 - val_accuracy: 0.8214
# Epoch 34/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.1484 - accuracy: 0.9659 - val_loss: 0.2958 - val_accuracy: 0.8631
# Epoch 35/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.1982 - accuracy: 0.9167 - val_loss: 0.1035 - val_accuracy: 0.8155
# Epoch 36/50
# 6/6 [==============================] - 6s 978ms/step - loss: 0.2028 - accuracy: 0.9205 - val_loss: 0.4570 - val_accuracy: 0.8333
# Epoch 37/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.1931 - accuracy: 0.9062 - val_loss: 0.2952 - val_accuracy: 0.8333
# Epoch 38/50
# 6/6 [==============================] - 6s 1s/step - loss: 0.1692 - accuracy: 0.9318 - val_loss: 0.3013 - val_accuracy: 0.8393
# Epoch 39/50
# 6/6 [==============================] - 6s 963ms/step - loss: 0.2273 - accuracy: 0.8958 - val_loss: 0.3692 - val_accuracy: 0.8214
# Epoch 40/50
# 6/6 [==============================] - 5s 911ms/step - loss: 0.1631 - accuracy: 0.9318 - val_loss: 0.4930 - val_accuracy: 0.8333
# Epoch 41/50
# 6/6 [==============================] - 6s 946ms/step - loss: 0.2664 - accuracy: 0.9062 - val_loss: 0.3169 - val_accuracy: 0.8631
# Epoch 42/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.1809 - accuracy: 0.9583 - val_loss: 0.3096 - val_accuracy: 0.8155
# Epoch 43/50
# 6/6 [==============================] - 9s 1s/step - loss: 0.1616 - accuracy: 0.9432 - val_loss: 0.5104 - val_accuracy: 0.8385
# Epoch 44/50
# 6/6 [==============================] - 9s 1s/step - loss: 0.1339 - accuracy: 0.9479 - val_loss: 0.4495 - val_accuracy: 0.8571
# Epoch 45/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.1397 - accuracy: 0.9432 - val_loss: 0.6481 - val_accuracy: 0.8333
# Epoch 46/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.2438 - accuracy: 0.8854 - val_loss: 0.4186 - val_accuracy: 0.8095
# Epoch 47/50
# 6/6 [==============================] - 7s 1s/step - loss: 0.1545 - accuracy: 0.9375 - val_loss: 0.4125 - val_accuracy: 0.8274
# Epoch 48/50
# 6/6 [==============================] - 6s 934ms/step - loss: 0.1354 - accuracy: 0.9659 - val_loss: 0.3475 - val_accuracy: 0.8274
# Epoch 49/50
# 6/6 [==============================] - 6s 974ms/step - loss: 0.1056 - accuracy: 0.9583 - val_loss: 1.2659 - val_accuracy: 0.8333
# Epoch 50/50
# 6/6 [==============================] - 6s 975ms/step - loss: 0.0841 - accuracy: 0.9886 - val_loss: 0.7597 - val_accuracy: 0.8073

# %%
# plotting out loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting the accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()
